# %% [markdown]
# # FHIR-Aggregator
# Explore data in the Google FHIR service.

# %% [markdown]
# # 1. Install the `fq` Query Tool

# %%
# !pip install -q fhir-aggregator-client

# %% [markdown]
# # 2. Verify Installation

# %%
# !fq
# Out:
# Usage: fq [OPTIONS] COMMAND [ARGS]...
#
#   FHIR-Aggregator utilities.
#
# Options:
#   --version  Show the version and exit.
#   --help     Show this message and exit.
#
# Commands:
#   ls          List all the installed GraphDefinitions.
#   run         Run GraphDefinition queries.
#   results     Work with the results of a GraphDefinition query.
#   vocabulary  FHIR-Aggregator's key Resources and CodeSystems.

# %% [markdown]
# # 3. Retrieve Vocabularies used on Commonly Used Resources

# %%
# %env FHIR_BASE=https://google-fhir.fhir-aggregator.org
# !fq vocabulary vocabulary.tsv --fhir-base-url $FHIR_BASE
# Out:
# env: FHIR_BASE=https://google-fhir.fhir-aggregator.org
# ✔ Wrote 29204 vocabularies to vocabulary.tsv

# %% [markdown]
# # 4. Show Vocabularies

# %%
import pandas as pd
df = pd.read_csv('vocabulary.tsv', sep='\t')
df
# Out:
#         research_study_identifiers               path  \
# 0      vestibular_schwannoma_mc_rc  Patient.extension
# 1      vestibular_schwannoma_mc_rc  Patient.extension
# 2      BEATAML1.0-COHORT,phs001657  Patient.extension
# 3      BEATAML1.0-COHORT,phs001657  Patient.extension
# 4      BEATAML1.0-COHORT,phs001657  Patient.extension
# ...                            ...                ...
# 29199                    HCMI-CMDC  Patient.extension
# 29200                    HCMI-CMDC  Patient.extension
# 29201                    HCMI-CMDC  Patient.extension
# 29202                    HCMI-CMDC  Patient.extension
# 29203                    HCMI-CMDC  Patient.extension
#
#                                            documentation  \
# 0      https://hl7.org/fhir/R4B/patient-definitions.h...
# 1      https://hl7.org/fhir/R4B/patient-definitions.h...
# 2      https://hl7.org/fhir/R4B/patient-definitions.h...
# 3      https://hl7.org/fhir/R4B/patient-definitions.h...
# ...
